# %%
import torch

class Entity:
    def __init__(self, hllset, identifier, references=None):
        self.hllset = hllset
        self.identifier = identifier
        self.references = references if references is not None else []

    def add_reference(self, entity):
        self.references.append(entity)

    def save_to_redis(self, redis_client):
        serialized_tensor = self.serialize_tensor(self.hllset)
        redis_client.set(self.identifier, serialized_tensor)

    @staticmethod
    def load_from_redis(redis_client, identifier):
        serialized_tensor = redis_client.get(identifier)
        if serialized_tensor is None:
            return None
        hllset = Entity.deserialize_tensor(serialized_tensor).cuda()
        return Entity(hllset, identifier)

    @staticmethod
    def serialize_tensor(tensor):
        buffer = io.BytesIO()
        torch.save(tensor, buffer)
        return buffer.getvalue()

    @staticmethod
    def deserialize_tensor(buffer):
        buffer = io.BytesIO(buffer)
        return torch.load(buffer)

def elementwise_union(tensor1, tensor2):
    assert tensor1.shape == tensor2.shape, "Tensors must have the same shape"
    return tensor1 | tensor2

def elementwise_intersection(tensor1, tensor2):
    assert tensor1.shape == tensor2.shape, "Tensors must have the same shape"
    return tensor1 & tensor2

def elementwise_xor(tensor1, tensor2):
    assert tensor1.shape == tensor2.shape, "Tensors must have the same shape"
    return tensor1 ^ tensor2

def elementwise_complement(tensor):
    return ~tensor

# %%
# Example usage
max_int64 = 2**63 - 10
tensor1 = torch.randint(0, max_int64, (1024,), dtype=torch.int64).cuda()
tensor2 = torch.randint(0, max_int64, (1024,), dtype=torch.int64).cuda()

union_result = elementwise_union(tensor1, tensor2)
intersection_result = elementwise_intersection(tensor1, tensor2)
xor_result = elementwise_xor(tensor1, tensor2)
complement_result = elementwise_complement(tensor1)

print("Union Result:\n", union_result)
print("Intersection Result:\n", intersection_result)
print("XOR Result:\n", xor_result)
print("Complement Result:\n", complement_result)
# Out:
# Union Result:
#  tensor([8779200116750787835, 8069323755752452854, 9221673701443105525,
#          ..., 9213118953410246071, 7491509169858410319,
#         3888717505835822718], device='cuda:0')
# Intersection Result:
#  tensor([2900329981963968520,  592654507737219776, 5206693427625853152,
#          ..., 2022257627576931328, 2325266023330152969,
#         2343588147121717250], device='cuda:0')
# XOR Result:
#  tensor([5878870134786819315, 7476669248015233078, 4014980273817252373,
#          ..., 7190861325833314743, 5166243146528257350,
#         1545129358714105468], device='cuda:0')
# Complement Result:
#  tensor([-4125750208646651994, -7817013255694848743, -6683892798729584886,
#          ..., -9122762985539679394, -7333319403748549196,
#         -2348411588737876031], device='cuda:0')

# %%
import torch
import mmh3
import random
import string

def generate_random_string(length=10):
    return ''.join(random.choices(string.ascii_letters + string.digits, k=length))

def murmurhash3_64(s):
    # Ensure the hash value is within the range of a 64-bit signed integer
    return mmh3.hash64(s)[0] & 0x7FFFFFFFFFFFFFFF

def reverse_bits(tensor):
    reversed_tensor = torch.zeros_like(tensor).cuda()
    for i in range(64):
        reversed_tensor |= ((tensor >> i) & 1) << (63 - i)
    return reversed_tensor

def process_hashes(hashes, result_tensor, p):
    # Calculate index from leading bits
    mask = (1 << p) - 1  # Create a mask with the lower p bits set to 1
    indices = (hashes >> (64 - p)) & mask
    
    # Calculate number of trailing zeros
    trailing_zeros = (hashes & -hashes).log2().long()
    
    # Update tensor
    for i in range(hashes.size(0)):
        idx = indices[i]
        z = trailing_zeros[i]
        
        # Extract the integer from the tensor at index idx
        value = result_tensor[idx]
        
        # Reverse the bits of the integer
        reversed_value = reverse_bits(value)
        
        # Update the bitmap with 1 at position z
        updated_value = reversed_value | (1 << z)
        
        # Convert the bitmap back to an integer
        final_value = reverse_bits(updated_value)
        
        # Save it back in the tensor at index idx
        result_tensor[idx] = final_value

# %%
# Parameters
num_batches = 10000
batch_size = 8192  # Increased batch size
p = 10  # Number of leading bits to use for index

# Initialize tensor to store results
result_tensor = torch.zeros(1 << p, dtype=torch.int64).cuda()

# Generate string batches and process
for batch_idx in range(num_batches):
    # Generate random strings
    strings = [generate_random_string() for _ in range(batch_size)]
    print(f"strins length: {strings.count}")
    # Remove duplicates by converting to a set
    unique_strings = list(set(strings))    
    print(f"unique_strins length: {unique_strings.count}")
    # Apply MurmurHash3 to convert strings to unsigned integers
    hashes = torch.tensor([murmurhash3_64(s) for s in unique_strings], dtype=torch.int64).cuda()
    print(f"hashes length: {hashes.size()}")
    # Process hashes and update result tensor
    process_hashes(hashes, result_tensor, p)
    
    # Print results for the current batch
    print(f"Batch {batch_idx + 1}/{num_batches}")
    # print("Result Tensor:\n", result_tensor)
# Out:
# strins length: <built-in method count of list object at 0x7fc2640ae480>
# unique_strins length: <built-in method count of list object at 0x7fc2641477c0>
# hashes length: torch.Size([8192])
# Batch 1/10000
# strins length: <built-in method count of list object at 0x7fc264a73b00>
# unique_strins length: <built-in method count of list object at 0x7fc258fb0340>
# hashes length: torch.Size([8192])
# Batch 2/10000
# strins length: <built-in method count of list object at 0x7fc258f4c940>
# unique_strins length: <built-in method count of list object at 0x7fc258f03e80>
# hashes length: torch.Size([8192])
# Batch 3/10000
# strins length: <built-in method count of list object at 0x7fc258fb0280>
# unique_strins length: <built-in method count of list object at 0x7fc258f46980>
# hashes length: torch.Size([8192])
# Batch 4/10000
# strins length: <built-in method count of list object at 0x7fc258f4c980>
# unique_strins length: <built-in method count of list object at 0x7fc258f1a3c0>
# hashes length: torch.Size([8192])
# Batch 5/10000
# strins length: <built-in method count of list object at 0x7fc2591f2c00>
# unique_strins length: <built-in method count of list object at 0x7fc258f55380>
# hashes length: torch.Size([8192])
# Batch 6/10000
# strins length: <built-in method count of list object at 0x7fc2591a4c80>
# unique_strins length: <built-in method count of list object at 0x7fc258f0bf00>
# hashes length: torch.Size([8192])
# Batch 7/10000
# strins length: <built-in method count of list object at 0x7fc2591bf7c0>
# unique_strins length: <built-in method count of list object at 0x7fc258f85700>
# hashes length: torch.Size([8192])
# Batch 8/10000
# strins length: <built-in method count of list object at 0x7fc258f02740>
# unique_strins length: <built-in method count of list object at 0x7fc258f22a40>
# hashes length: torch.Size([8192])
# Batch 9/10000
# strins length: <built-in method count of list object at 0x7fc258f2fc80>
# unique_strins length: <built-in method count of list object at 0x7fc258f61480>
# hashes length: torch.Size([8192])
# Batch 10/10000
# strins length: <built-in method count of list object at 0x7fc264958d40>
# unique_strins length: <built-in method count of list object at 0x7fc258f05a40>
# hashes length: torch.Size([8192])
# Batch 11/10000
# strins length: <built-in method count of list object at 0x7fc258f578c0>
# unique_strins length: <built-in method count of list object at 0x7fc258fab640>
# hashes length: torch.Size([8192])
# Batch 12/10000
# strins length: <built-in method count of list object at 0x7fc258f05a40>
# unique_strins length: <built-in method count of list object at 0x7fc258f1dd80>
# hashes length: torch.Size([8192])
# Batch 13/10000
# strins length: <built-in method count of list object at 0x7fc258fab640>
# unique_strins length: <built-in method count of list object at 0x7fc258f89f00>
# hashes length: torch.Size([8192])
# Batch 14/10000
# strins length: <built-in method count of list object at 0x7fc258f1dd80>
# unique_strins length: <built-in method count of list object at 0x7fc258f120c0>
# hashes length: torch.Size([8192])
# Batch 15/10000
# strins length: <built-in method count of list object at 0x7fc258f89f00>
# unique_strins length: <built-in method count of list object at 0x7fc258f761c0>
# hashes length: torch.Size([8192])
# Batch 16/10000
# strins length: <built-in method count of list object at 0x7fc258f120c0>
# unique_strins length: <built-in method count of list object at 0x7fc258f0e300>
# hashes length: torch.Size([8192])
# Batch 17/10000
# strins length: <built-in method count of list object at 0x7fc258f761c0>
# unique_strins length: <built-in method count of list object at 0x7fc258f96480>
# hashes length: torch.Size([8192])
# Batch 18/10000
# strins length: <built-in method count of list object at 0x7fc258f0e300>
# unique_strins length: <built-in method count of list object at 0x7fc258f2a600>
# hashes length: torch.Size([8192])
# Batch 19/10000
# strins length: <built-in method count of list object at 0x7fc258f96480>
# unique_strins length: <built-in method count of list object at 0x7fc258f36700>
# hashes length: torch.Size([8192])
# Batch 20/10000
# strins length: <built-in method count of list object at 0x7fc258f2a600>
# unique_strins length: <built-in method count of list object at 0x7fc258f26800>
# hashes length: torch.Size([8192])
# Batch 21/10000
# strins length: <built-in method count of list object at 0x7fc258f36700>
# unique_strins length: <built-in method count of list object at 0x7fc258f4a900>
# hashes length: torch.Size([8192])
# Batch 22/10000
# strins length: <built-in method count of list object at 0x7fc258f26800>
# unique_strins length: <built-in method count of list object at 0x7fc2591ee980>
# hashes length: torch.Size([8192])
# Batch 23/10000
# strins length: <built-in method count of list object at 0x7fc258f4a900>
# unique_strins length: <built-in method count of list object at 0x7fc258f6aa40>
# hashes length: torch.Size([8192])
# Batch 24/10000
# strins length: <built-in method count of list object at 0x7fc2591ee980>
# unique_strins length: <built-in method count of list object at 0x7fc2591e2bc0>
# hashes length: torch.Size([8192])
# Batch 25/10000
# strins length: <built-in method count of list object at 0x7fc258f6aa40>
# unique_strins length: <built-in method count of list object at 0x7fc258fa6d00>
# hashes length: torch.Size([8192])
# Batch 26/10000
# strins length: <built-in method count of list object at 0x7fc2591e2bc0>
# unique_strins length: <built-in method count of list object at 0x7fc2591eae40>
# hashes length: torch.Size([8192])
# Batch 27/10000
# strins length: <built-in method count of list object at 0x7fc258fa6d00>
# unique_strins length: <built-in method count of list object at 0x7fc258f7af80>
# hashes length: torch.Size([8192])
# Batch 28/10000
# strins length: <built-in method count of list object at 0x7fc2591eae40>
# unique_strins length: <built-in method count of list object at 0x7fc2591b3180>
# hashes length: torch.Size([8192])
# Batch 29/10000
# strins length: <built-in method count of list object at 0x7fc258f7af80>
# unique_strins length: <built-in method count of list object at 0x7fc258f3b340>
# hashes length: torch.Size([8192])
# Batch 30/10000
# strins length: <built-in method count of list object at 0x7fc2591b3180>
# unique_strins length: <built-in method count of list object at 0x7fc2591c7480>
# hashes length: torch.Size([8192])
# Batch 31/10000
# strins length: <built-in method count of list object at 0x7fc258f3b340>
# unique_strins length: <built-in method count of list object at 0x7fc258fa3500>
# hashes length: torch.Size([8192])
# Batch 32/10000
# strins length: <built-in method count of list object at 0x7fc2591c7480>
# unique_strins length: <built-in method count of list object at 0x7fc2591db680>
# hashes length: torch.Size([8192])
# Batch 33/10000
# strins length: <built-in method count of list object at 0x7fc258fa3500>
# unique_strins length: <built-in method count of list object at 0x7fc258f43780>
# hashes length: torch.Size([8192])
# Batch 34/10000
# strins length: <built-in method count of list object at 0x7fc2591db680>
# unique_strins length: <built-in method count of list object at 0x7fc2591cf900>
# hashes length: torch.Size([8192])
# Batch 35/10000
# strins length: <built-in method count of list object at 0x7fc258f43780>
# unique_strins length: <built-in method count of list object at 0x7fc258f8f9c0>
# hashes length: torch.Size([8192])
# Batch 36/10000
# strins length: <built-in method count of list object at 0x7fc2591cf900>
# unique_strins length: <built-in method count of list object at 0x7fc2591b7b00>
# hashes length: torch.Size([8192])
# Batch 37/10000
# strins length: <built-in method count of list object at 0x7fc258f8f9c0>
# unique_strins length: <built-in method count of list object at 0x7fc258f9fb40>
# hashes length: torch.Size([8192])
# Batch 38/10000
# strins length: <built-in method count of list object at 0x7fc2591b7b00>
# unique_strins length: <built-in method count of list object at 0x7fc2591ffc80>
# hashes length: torch.Size([8192])
# Batch 39/10000
# strins length: <built-in method count of list object at 0x7fc258f9fb40>
# unique_strins length: <built-in method count of list object at 0x7fc258f67dc0>
# hashes length: torch.Size([8192])
# Batch 40/10000
# strins length: <built-in method count of list object at 0x7fc2591ffc80>
# unique_strins length: <built-in method count of list object at 0x7fc2591cbec0>
# hashes length: torch.Size([8192])
# Batch 41/10000
# strins length: <built-in method count of list object at 0x7fc258f67dc0>
# unique_strins length: <built-in method count of list object at 0x7fc258f93fc0>
# hashes length: torch.Size([8192])
# Batch 42/10000
# strins length: <built-in method count of list object at 0x7fc2591cbec0>
# unique_strins length: <built-in method count of list object at 0x7fc258fb40c0>
# hashes length: torch.Size([8192])
# Batch 43/10000
# strins length: <built-in method count of list object at 0x7fc258f93fc0>
# unique_strins length: <built-in method count of list object at 0x7fc258f6c1c0>
# hashes length: torch.Size([8192])
# Batch 44/10000
# strins length: <built-in method count of list object at 0x7fc258fb40c0>
# unique_strins length: <built-in method count of list object at 0x7fc2591f8280>
# hashes length: torch.Size([8192])
# Batch 45/10000
# strins length: <built-in method count of list object at 0x7fc258f6c1c0>
# unique_strins length: <built-in method count of list object at 0x7fc258f7c300>
# hashes length: torch.Size([8192])
# Batch 46/10000
# strins length: <built-in method count of list object at 0x7fc2591f8280>
# unique_strins length: <built-in method count of list object at 0x7fc2591c0380>
# hashes length: torch.Size([8192])
# Batch 47/10000
# strins length: <built-in method count of list object at 0x7fc258f7c300>
# unique_strins length: <built-in method count of list object at 0x7fc258fac440>
# hashes length: torch.Size([8192])
# Batch 48/10000
# strins length: <built-in method count of list object at 0x7fc2591c0380>
# unique_strins length: <built-in method count of list object at 0x7fc2591e4580>
# hashes length: torch.Size([8192])
# Batch 49/10000
# strins length: <built-in method count of list object at 0x7fc258fac440>
# unique_strins length: <built-in method count of list object at 0x7fc258f50600>
# hashes length: torch.Size([8192])
# Batch 50/10000
# strins length: <built-in method count of list object at 0x7fc2591e4580>
# unique_strins length: <built-in method count of list object at 0x7fc2591b8740>
# hashes length: torch.Size([8192])
# Batch 51/10000
# strins length: <built-in method count of list object at 0x7fc258f50600>
# unique_strins length: <built-in method count of list object at 0x7fc258f3c780>
# hashes length: torch.Size([8192])
# Batch 52/10000
# strins length: <built-in method count of list object at 0x7fc2591b8740>
# unique_strins length: <built-in method count of list object at 0x7fc2591dc900>
# hashes length: torch.Size([8192])
# Batch 53/10000
# strins length: <built-in method count of list object at 0x7fc258f3c780>
# unique_strins length: <built-in method count of list object at 0x7fc258f80ac0>
# hashes length: torch.Size([8192])
# Batch 54/10000
# strins length: <built-in method count of list object at 0x7fc2591dc900>
# unique_strins length: <built-in method count of list object at 0x7fc2591d0c40>
# hashes length: torch.Size([8192])
# Batch 55/10000
# strins length: <built-in method count of list object at 0x7fc258f80ac0>
# unique_strins length: <built-in method count of list object at 0x7fc258f5cd00>
# hashes length: torch.Size([8192])
# Batch 56/10000
# strins length: <built-in method count of list object at 0x7fc2591d0c40>
# unique_strins length: <built-in method count of list object at 0x7fc2591d4e40>
# hashes length: torch.Size([8192])
# Batch 57/10000
# strins length: <built-in method count of list object at 0x7fc258f5cd00>
# unique_strins length: <built-in method count of list object at 0x7fc258f58fc0>
# hashes length: torch.Size([8192])
# Batch 58/10000
# strins length: <built-in method count of list object at 0x7fc2591d4e40>
# unique_strins length: <built-in method count of list object at 0x7fc258f59080>
# hashes length: torch.Size([8192])
# Batch 59/10000
# strins length: <built-in method count of list object at 0x7fc258f58fc0>
# unique_strins length: <built-in method count of list object at 0x7fc258f59100>
# hashes length: torch.Size([8192])
# Batch 60/10000
# strins length: <built-in method count of list object at 0x7fc258f59080>
# unique_strins length: <built-in method count of list object at 0x7fc258f591c0>
# hashes length: torch.Size([8192])

# %%
from transformers import AutoTokenizer
from torch.utils.data import DataLoader, Dataset

class GenericTokenizer:
    def __init__(self, model_name):
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
    
    def tokenize(self, text):
        # Tokenize the text and return tokenized tokens as a string collection
        tokens = self.tokenizer.tokenize(text)
        return tokens

# %%
class BertTokenizerWrapper(GenericTokenizer):
    def __init__(self):
        super().__init__('bert-base-uncased')

class RobertaTokenizerWrapper(GenericTokenizer):
    def __init__(self):
        super().__init__('roberta-base')

class GPT2TokenizerWrapper(GenericTokenizer):
    def __init__(self):
        super().__init__('gpt2')
        
class TextDataset(Dataset):
    def __init__(self, texts):
        self.texts = texts
    
    def __len__(self):
        return len(self.texts)
    
    def __getitem__(self, idx):
        return self.texts[idx]

# %%
# Example text data
texts = [
    "Hello, how are you?",
    "Transformers are amazing!",
    "Let's tokenize this text."
]

# Create dataset and dataloader
dataset = TextDataset(texts)
dataloader = DataLoader(dataset, batch_size=2, shuffle=False)

# Instantiate a tokenizer wrapper (e.g., BERT)
tokenizer = BertTokenizerWrapper()

# Tokenize text data using the dataloader
for batch in dataloader:
    for text in batch:
        tokens = tokenizer.tokenize(text)
        print(f"Original Text: {text}")
        print(f"Tokenized Tokens: {tokens}")
# Out:
# Original Text: Hello, how are you?
# Tokenized Tokens: ['hello', ',', 'how', 'are', 'you', '?']
# Original Text: Transformers are amazing!
# Tokenized Tokens: ['transformers', 'are', 'amazing', '!']
# Original Text: Let's tokenize this text.
# Tokenized Tokens: ['let', "'", 's', 'token', '##ize', 'this', 'text', '.']
# /home/alexmy/JULIA/SGS/SGS/venv/lib64/python3.10/site-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
